# %%
import pandas as pd

df = pd.read_csv('아파트(매매)__실거래가_20220808114117.csv', encoding='cp949')
df.가격 = df.가격.str.replace(',', '').astype('int64')
df.가격 > 100000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14766    False
# 14767    False
# 14768    False
# 14769    False
# 14770    False
# Name: 가격, Length: 14771, dtype: bool

# %%
df = df[['지역', '단지명', '면적', '가격', '건축년도']]
df.loc[df['지역'].str.contains(r'대구')]

#gs = df[df.지역.str.find('군산') > -1]
#dg = df[df.지역.str.find('대구광역시') > -1]
#bs = df[df.지역.str.find('부산광역시') > -1]
# Out:
#                  지역              단지명        면적     가격  건축년도
# 6842   대구광역시 남구 대명동             경일맨션   70.3500  13500  1977
# 6843   대구광역시 남구 대명동       교대역하늘채뉴센트원   74.7212  46510  2022
# 6844   대구광역시 남구 대명동           대명헤리티지   84.6000  40800  2022
# 6845   대구광역시 남구 대명동             삼성공원   44.5200   8300  1983
# 6846   대구광역시 남구 대명동          서동해피플러스   84.6050  21000  2007
# ...             ...              ...       ...    ...   ...
# 8897  부산광역시 해운대구 중동  우성빌라(백세해운대빌라2차)  134.5050  68500  1994
# 8898  부산광역시 해운대구 중동            토명비치빌   83.8600  22300  2003
# 8899  부산광역시 해운대구 중동      해운대양우내안애팰리스   78.3482  37000  2013
# 8900  부산광역시 해운대구 중동       해운대힐스테이트위브  105.8829  94000  2015
# 8901  부산광역시 해운대구 중동           현우산호맨션   51.3000  19000  1987
#
# [749 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 30))
sns.countplot(y=gs['지역'], order=gs['지역'].value_counts().index)
plt.yticks(fontsize=12)
plt.title('7월 지역별 아파트 거래 수')
plt.show()

# %%
plt.figure(figsize=(12, 50))
bs.loc[bs['건축년도'] > 2010].groupby('지역')['건축년도'].count().sort_values().plot(kind='barh', color='royalblue')
plt.yticks(fontsize=12)
plt.title('7월 부산 부동산 2010년 이상 건축 아파트 거래현황')

plt.show()

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pylab as plt

labels = bs
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 10>()
#       8 explode = (0, 0.1, 0, 0)
#       9 plt.title("Pie Chart")
# ---> 10 plt.pie(sizes, explode=explode, labels=labels, colors=colors,
#      11         autopct='%1.1f%%', shadow=True, startangle=90)
#      12 plt.axis('equal')
#      13 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2756, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2749 @_copy_docstring_and_deprecators(Axes.pie)
#    2750 def pie(
#    2751         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2754         textprops=None, center=(0, 0), frame=False,
# ...
