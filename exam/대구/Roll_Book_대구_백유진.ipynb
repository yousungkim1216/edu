# %%
import pandas as pd

df1 = pd.read_excel("roll_book.xlsx", sheet_name=0)
df1
# Out:
#      이름  학년  반
# 0   강루아   1  1
# 1   김재민   1  1
# 2   박윤주   1  1
# 3   김영선   1  2
# 4   이새별   1  5
# ..  ...  .. ..
# 63  양가연   6  2
# 64  김민규   6  3
# 65  박지원   6  3
# 66  윤지원   6  5
# 67  정유정   6  5
#
# [68 rows x 3 columns]

# %%
df2 = pd.read_excel("roll_book.xlsx", sheet_name=1)
df2
# Out:
#      이름 수강반
# 0   강루아  A반
# 1   김재민  A반
# 2   박윤주  A반
# 3   김영선  A반
# 4   이새별  A반
# ..  ...  ..
# 63  양가연  C반
# 64  김민규  C반
# 65  박지원  C반
# 66  윤지원  C반
# 67  정유정  C반
#
# [68 rows x 2 columns]

# %%
df3 = df1.merge(df2, on="이름", how="left")
df3
# Out:
#      이름  학년  반 수강반
# 0   강루아   1  1  A반
# 1   김재민   1  1  A반
# 2   박윤주   1  1  A반
# 3   김영선   1  2  A반
# 4   이새별   1  5  A반
# ..  ...  .. ..  ..
# 63  양가연   6  2  C반
# 64  김민규   6  3  C반
# 65  박지원   6  3  C반
# 66  윤지원   6  5  C반
# 67  정유정   6  5  C반
#
# [68 rows x 4 columns]

# %%
pdf1 = df3.pivot_table("이름",index="수강반", aggfunc="count")
pdf1
# Out:
#      이름
# 수강반
# A반   23
# B반   23
# C반   22

# %%
pdf2 = df3.pivot_table("이름",index="학년", aggfunc="count")
pdf2
# Out:
#     이름
# 학년
# 1    9
# 2   14
# 3   19
# 4   15
# 5    5
# 6    6

# %%
pdf3 = df3.pivot_table("이름",index=["학년","수강반"], aggfunc="count")
pdf3
# Out:
#         이름
# 학년 수강반
# 1  A반    9
# 2  A반   14
# 3  B반   12
#    C반    7
# 4  B반    9
#    C반    6
# 5  B반    1
#    C반    4
# 6  B반    1
#    C반    5

# %%
labels = pdf2.index
group_sizes = pdf2['이름']

explode = (0,0,0.1,0,0,0)
plt.title("Rool-Book")
plt.pie(group_sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()
