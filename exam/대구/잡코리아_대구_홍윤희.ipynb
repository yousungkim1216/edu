# %%
import urllib
from bs4 import BeautifulSoup as bs
import pandas as pd

base_url = 'http://www.jobkorea.co.kr/Search/?stext={}&tabType=recruit&Page_No={}'

# %%
def crawl(keyword, page_num):
    keyword = urllib.parse.quote(keyword)
    url = base_url.format(keyword,page_num)
    response = urllib.request.urlopen(url)
    soup = bs(response,'html.parser')
    name = [element.text for element in soup.select("a.name")][:19]
    detail = [element.text for element in soup.select("div.post-list-info > a.title")][:19]
    detail = [element.replace("\n","").replace("\r","") for element in detail]
    df = pd.DataFrame({'기업 이름' : name, '상세 내용' : detail})
    return df

# %%
crawl('인공지능',10)
# Out:
#                기업 이름                                              상세 내용
# 0               퓨처메인  인공지능/ML/DL/Data-science/설비 데이터기반 AI개발자 경력직 모집 ...
# 1              에버엑스㈜                                  AI Software En...
# 2              에버엑스㈜                                  AI Research Sc...
# 3         ㈜미디어그룹사람과숲                                  [주5일/일반사무] 인공지...
# 4                ㈜이튜                                  [주5일/초보가능] AI ...
# 5               ㈜휴위드                                  통신사 AI서비스 관리담당...
# 6           ㈜슈퍼브에이아이                                  Superb AI - Pr...
# 7   파이프트리스마트팜㈜(PAIPT                                  [파이프트리] Data A...
# 8            브레인컨테이너  인공지능(AI) 자율주행 LiDAR 데이터 가공                    ...
# 9           주식회사 고피자                                  [GOPIZZA 채용] 미...
# 10         ㈜사람인에이치에스                                  [한화그룹사/자율출퇴근/월...
# 11             ㈜에이든랩                                  에이든랩 R&D본부 AI ...
# 12            노아시스템㈜                                  의료 영상 인공지능(AI)...
# 13              이산기술                                  2021 상반기 AI 개발...
# 14            모두의연구소                                  [고용노동부x모두의연구소]...
# 15                로민                                  [로민] AI 플랫폼, 백...
# 16            ㈜이브이패스                                  데이터분석 - Data 분...
# 17             ㈜맥스테드  인공지능 학습용 데이터 구축 크라우드 워커를 모십니다.(출근)라벨러경험자 우대   ...
# 18             ㈜컨셉터스                                  빅데이터 AI플랫폼 iOS...

# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime

# %%
f = open('jobkorea_apply_urls.csv', 'w')
f.write('date, 회사명, 직무, URL, 경력, 위치, 지원방식' + '\n')
keyword = '파이썬'    # 키워드

# %%
for n in range(1,20)  :
    raw = requests.get("https://www.jobkorea.co.kr/Search/?stext={}&tabType=recruit&Page_No=".format(keyword) +str(n)
                   , headers ={'User-Agent':'Mozilla/5.0'})
    html = BeautifulSoup(raw.text, "html.parser")
    results = html.select("li.list-post")
    
    for ar in results[0:20]: 
        company_name = ar.select_one("a.name").text.strip() 
        detail = ar.select_one("a.title").text.strip()  
        url =   'https://www.jobkorea.co.kr'+ar.find("a")['href']
        exp =   ar.select_one("span.exp").text.strip()
        location = ar.select_one("span.loc").text.strip()
        apply = ar.select_one("div.post-list-apply").text.strip()
        company_name = company_name.replace(",", "")
        detail = detail.replace(",", "")
        location = location.replace(" 외", "")
        now = datetime.datetime.now()
        nowDate = now.strftime('%Y-%m-%d')
        f.write(nowDate + ',' + company_name + ',' + detail + ',' + url + ',' + exp + ',' + location +','+ apply+'\n') 
        time.sleep(1) #1초
    print(str(n)+"번째 페이지 내 " + str(keyword) + " 의 채용공고 크롤링을 완료했습니다.")
    print("최종 엑셀 작업 마무리중 입니다.")
  
f.close()
print("잡코리아 크롤링이 완료되었습니다.")
# Out:
# 1번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 2번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 3번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 4번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 5번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 6번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 7번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 8번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 9번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 10번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 11번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 12번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 13번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 14번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 15번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 16번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 17번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 18번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 19번째 페이지 내 파이썬 의 채용공고 크롤링을 완료했습니다.
# 최종 엑셀 작업 마무리중 입니다.
# 잡코리아 크롤링이 완료되었습니다.
